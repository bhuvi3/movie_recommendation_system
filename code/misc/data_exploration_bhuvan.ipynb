# %%
import numpy as np
import pickle

# %%
ratings_file = "../../data/ratings.csv"
ratings_mat_file = "../../data/ratings_mat.pickle"

# %%
with open(ratings_mat_file, "rb") as fp:
    ratings_mat = pickle.load(fp)

# %%
ratings_mat[12]
# Out:
# {1: '4.0',
#  16: '4.0',
#  17: '4.0',
#  29: '5.0',
#  32: '2.0',
#  34: '5.0',
#  36: '3.0',
#  47: '5.0',
#  50: '5.0',
#  73: '2.0',
#  82: '4.0',
#  97: '4.0',
#  123: '5.0',
#  125: '5.0',
#  150: '5.0',
#  155: '1.0',
#  157: '1.0',
#  160: '1.0',
#  162: '4.0',
#  175: '5.0',
#  176: '4.0',
#  194: '5.0',
#  198: '1.0',
#  223: '5.0',
#  232: '4.0',
#  235: '5.0',
#  246: '5.0',
#  247: '5.0',
#  260: '5.0',
#  273: '3.0',
#  290: '5.0',
#  293: '4.0',
#  296: '5.0',
#  301: '2.0',
#  307: '5.0',
#  309: '4.0',
#  318: '4.0',
#  322: '5.0',
#  334: '3.0',
#  337: '4.0',
#  348: '4.0',
#  356: '3.0',
#  363: '4.0',
#  373: '5.0',
#  441: '4.0',
#  446: '5.0',
#  457: '3.0',
#  475: '3.0',
#  492: '4.0',
#  497: '4.0',
#  501: '5.0',
#  523: '3.0',
#  527: '5.0',
#  529: '4.0',
#  535: '4.0',
#  541: '4.0',
#  549: '5.0',
#  555: '3.0',
#  568: '3.0',
#  581: '5.0',
#  589: '3.0',
#  590: '4.0',
#  593: '4.0',
#  595: '3.0',
#  608: '5.0',
#  728: '4.0',
#  735: '5.0',
# ...

# %%
np.float16("3.5")
# Out:
# 3.5
